# %% [markdown]
# #PRACTICAL 3
# ##Study of list & Various operations on it
# ###Bidisha Chaudhuri PRN:25070123034
# ###EnTC Batch A2

# %%
## Python lists
thislist = ["apple", "guava", "watermelon"]
print(thislist)     ##Instead of doubl quotes, single quotes can be used, but preferred - double quotes
# Out:
# ['apple', 'guava', 'watermelon']

# %%
#Allow Duplicates
thislist = ["apple", "guava", "apple", "watermelon", "guava"]
print(thislist)
# Out:
# ['apple', 'guava', 'apple', 'watermelon', 'guava']

# %%
list1 = [1,2,'symbi', 54]
list1[0]
# Out:
# 1

# %%
#List Length
thislist = ["apple", 'guava', 'watermelon']
print(len(thislist))
# Out:
# 3

# %%
#A list with strings, integers, and boolean values:
list1 = ["abc", 34, True, 40, "female", False]  ##True & False are boolean functions

# %%
#Access Items
thislist = ["apple", "cherry", "litchi"]
print(thislist[1])
# Out:
# cherry

# %%
#Reverse/Negative Indexing
thislist = ["apple", "chery", "guava"]
print(thislist[-2])
# Out:
# chery

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[:4])
# Out:
# ['apple', 'guava', 'cherry', 'orange']

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[-3:-1])
# Out:
# ['kiwi', 'melon']

# %%
#Slicing
thislist = ["apple", "guava", "cherry","orange", "kiwi", "melon", "mango"]
print(thislist[-3:])
# Out:
# ['kiwi', 'melon', 'mango']

# %%
#Change Item Value
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrent"
print(thislist)
# Out:
# ['apple', 'blackcurrent', 'cherry']

# %%
thislist = ["school", "college", "office"]
thislist[1] = "university"
thislist[2] = "workplace"
print(thislist)
# Out:
# ['school', 'university', 'workplace']

# %%
#Append Items
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")   #Append means to add it at the end
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
#Insert Items
thislist = ["apple", "banana", "cherry"]
thislist.insert(2,"orange")
print(thislist)
# Out:
# ['apple', 'banana', 'orange', 'cherry']

# %%
#Extend List
thislist = ["apple", "banana", "cherry"]
tropical = ["mango","pineappple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineappple', 'papaya']

# %%
8 in [3,4,5]
# Out:
# False

# %%
list = ('-Symbi')*6
#list1(1,2,3) - this will give error
print(list)
# Out:
# -Symbi-Symbi-Symbi-Symbi-Symbi-Symbi

# %%
L = ['spam', 'Spam', 'SPAM']
print(L[0])
# Out:
# spam

# %%
numbers = [10, 20, 30, 40, 50]
#Slicing examples
"Elements from index 1 to 3:"
"First three elements: "
"Elements from index 2 onwards: "
"All elements: "
# Out:
# 'All elements: '

# %%
#Problem Statements
marks = [99,80,78,56,39]
marks1 = max(marks)
print("The highest marks obtained is: ",marks1)
marks2 = min(marks)
print("The lowest marks obtaind is: ",marks2)
marks.sort()      #To arrange in ascending order
print(marks)
# Out:
# The highest marks obtained is:  99
# The lowest marks obtaind is:  39
# [39, 56, 78, 80, 99]

# %%
numbers = [1,2,3,4,5,6]
print(max(numbers))
print(min(numbers))
print(sum(numbers))
print(len(numbers))
numbers.sort()
print(numbers)
# Out:
# 6
# 1
# 21
# 6
# [1, 2, 3, 4, 5, 6]

# %%
#Grocery Shopping List problem statement 1

grocery = ["banana", "cauliflower", "onions","potato", "tomato"]
grocery.insert(3,"cherry")
grocery.append("carrot")
grocery.remove("banana")
print(grocery)
# Out:
# ['cauliflower', 'onions', 'cherry', 'potato', 'tomato', 'carrot']

# %%
#Phone Contact problem statement 2
#Create a list of contacts, add a new contact, delete an existing contact, display contacts alphabetically

contact = ["Prithvi", "Aksharr", "Abhilasha", "Shreeya", "Shatakshi", "Dolly","Anushka", "Amay"]
contact.insert(4,"Vaibhav")
contact.append("Lakshay")
contact.remove("Amay")
contact.sort()
print(contact)
# Out:
# ['Abhilasha', 'Aksharr', 'Anushka', 'Dolly', 'Lakshay', 'Prithvi', 'Shatakshi', 'Shreeya', 'Vaibhav']

# %%
#Problem Statement 2 contd.
contact = ["Prithvi", "Aksharr", "Abhilasha", "Shreeya", "Shatakshi", "Dolly","Anushka", "Amay"]
contact.insert(4,"Vaibhav")
contact.remove("Amay")
print(contact)
# Out:
# ['Prithvi', 'Aksharr', 'Abhilasha', 'Shreeya', 'Vaibhav', 'Shatakshi', 'Dolly', 'Anushka']

# %%
#Temperature Analysis problem statement 3

temperature = [25, 24, 17, 19, 16, 20, 22, 29, 12, 10]

#Temperatures for the first 5 days
print(temperature[0:5])
# Out:
# [25, 24, 17, 19, 16]

# %%
#Problem statement 3 contd.

temperature = [25, 24, 17, 19, 16, 20, 22, 29, 12, 10]

#Temperatures for the last 5 days
print(temperature[-5:])
# Out:
# [20, 22, 29, 12, 10]

# %%
#Problem statement 3 contd.
temperature = [25, 24, 17, 19, 16, 20, 22, 29, 12, 10]
#Highest and Lowest Temperatures
max = max(temperature)
print("The highest temperature is: ", max)
print("The lowest temperature is: ", min(temperature))
a = sum(temperature)
b = len(temperature)
print("The average of the temperatures is: ", a/b)
# Out:
# The highest temperature is:  29
# The lowest temperature is:  10
# The average of the temperatures is:  19.4
